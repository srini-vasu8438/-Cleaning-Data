# %%
# !pip install textblob

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from textblob import TextBlob
import seaborn as sns

# Load the dataset
csv_file_path = "D:/clianing data/AB_NYC_2019.csv.zip"
df = pd.read_csv(csv_file_path)

# Drop rows with missing listing names
df = df.dropna(subset=['name'])

# Function to get sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Apply sentiment analysis
df['sentiment'] = df['name'].apply(get_sentiment)

# Categorize sentiment
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['sentiment_category'] = df['sentiment'].apply(categorize_sentiment)

# Plot sentiment distribution
plt.figure(figsize=(8, 5))
sns.countplot(x=df['sentiment_category'], hue=df['neighbourhood_group'], palette='coolwarm')
plt.title('Sentiment Analysis of Listing Titles')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# Display sample results
print(df[['name', 'sentiment', 'sentiment_category']].head())
# Out:
#                                                name  sentiment  \
# 0                Clean & quiet apt home by the park   0.322222
# 1                             Skylit Midtown Castle   0.000000
# 2               THE VILLAGE OF HARLEM....NEW YORK !   0.000000
# 3                   Cozy Entire Floor of Brownstone  -0.100000
# 4  Entire Apt: Spacious Studio/Loft by central park   0.200000
#
#   sentiment_category
# 0           Positive
# 1            Neutral
# 2            Neutral
# 3           Negative
# 4           Positive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob

# %%
csv_file_path = "D:/clianing data/CAvideos.csv.zip"
df = pd.read_csv(csv_file_path)

# %%
df = df.dropna(subset=['title', 'description'])

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
df['title_sentiment'] = df['title'].apply(get_sentiment)
df['desc_sentiment'] = df['description'].apply(get_sentiment)

# %%
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['title_sentiment_category'] = df['title_sentiment'].apply(categorize_sentiment)
df['desc_sentiment_category'] = df['desc_sentiment'].apply(categorize_sentiment)

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x=df['title_sentiment_category'], hue=df['desc_sentiment_category'], palette='coolwarm')
plt.title('Sentiment Analysis of YouTube Video Titles and Descriptions')
plt.xlabel('Title Sentiment')
plt.ylabel('Count')
plt.legend(title='Description Sentiment')
plt.show()

# %%
print(df[['title', 'title_sentiment', 'title_sentiment_category',
          'description', 'desc_sentiment', 'desc_sentiment_category']].head())
# Out:
#                                                title  title_sentiment  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé              0.0
# 1                      PLUSH - Bad Unboxing Fan Mail             -0.7
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...              0.0
# 3                           I Dare You: GOING BALD!?              0.0
# 4        Ed Sheeran - Perfect (Official Music Video)              1.0
#
#   title_sentiment_category                                        description  \
# 0                  Neutral  Eminem's new track Walk on Water ft. Beyoncé i...
# 1                 Negative  STill got a lot of packages. Probably will las...
# 2                  Neutral  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3                  Neutral  I know it's been a while since we did this sho...
# 4                 Positive  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...
#
#    desc_sentiment desc_sentiment_category
# ...
